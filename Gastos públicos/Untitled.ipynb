# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

data = pd.read_csv('Ano-2017.csv', sep= ';')

data.head()
# Out:
#    txNomeParlamentar  ideCadastro  nuCarteiraParlamentar  nuLegislatura sgUF  \
# 0  ABEL MESQUITA JR.     178957.0                    1.0         2015.0   RR
# 1  ABEL MESQUITA JR.     178957.0                    1.0         2015.0   RR
# 2  ABEL MESQUITA JR.     178957.0                    1.0         2015.0   RR
# 3  ABEL MESQUITA JR.     178957.0                    1.0         2015.0   RR
# 4  ABEL MESQUITA JR.     178957.0                    1.0         2015.0   RR
#
#   sgPartido  codLegislatura  numSubCota  \
# 0       DEM            55.0           1
# 1       DEM            55.0           1
# 2       DEM            55.0           3
# 3       DEM            55.0           3
# 4       DEM            55.0           3
#
#                                         txtDescricao  numEspecificacaoSubCota  \
# 0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...                        0
# 1  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...                        0
# ...

# %%
parlamentar = data['txNomeParlamentar'].unique()

p3 = parlamentar[0:4]

print(p3)
# Out:
# ['ABEL MESQUITA JR.' 'ADAIL CARNEIRO' 'ADALBERTO CAVALCANTI'
#  'ADELMO CARNEIRO LEÃO']

# %%
plt.scatter(, data['vlrDocumento'])
plt.show()
